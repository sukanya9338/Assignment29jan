# %%
1.who developed python programming language?
A.Guido van Rossum
#2.which type of programming does python support?
A.python is interpreted programmimg language, supporting object-oriented, structure and functional programmming language.
3.is python case sensitive when dealing with identifiers?
A.yes
4.What is the correct extension of the python files?
A. .py, .pyi, .pyc, .pyd, .pyo, .pyw, and .pyz.
5.is python code compiled or interpreted?
A.it is first compiled and then interpreted line by line.
6.Name a few block of code is used to define in python language.
A.A modules,a fuction, a class 
7.State a character used to give a single -line comments in python.
A.Hash character(#).
8.Mention a function which help use to find the version of python on that we are currently workin on.
A. Using python_version() function
9.python supports the creation of anonymous function at runtime useing a construct called
A.the lambda keyword
10.what does pip stand for python.
A.pip install packages.
11.Mention a few built-in-functions in python.
A.  print(), abs(), round(), min(), max(), sorted(), sum(), and len()
12.what is the maximum possible length of an identifier in python.
A.79 charaters
13.how is memory managed in python.
A.internal use and non-object memory.
14.what are the benefits of useing python.
A.Libraries help reduce coding errors, make programmers more efficient, and make software smaller in size.
15.how to install python on windows and set the path variables.
A.Right click on My Computer and click on properties.
Click on Advanced System settings.
Click on Environment Variable tab.
Click on new tab of user variables.
Write path in variable name.
Copy the path of Python folder.
Paste path of Python in variable value. Click on Ok button: Click on Ok button:
16.is indentation required in python.
A.the indentation in Python is very important. Python uses to indicate a block of code.
